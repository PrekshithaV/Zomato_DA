# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:root@localhost/test

# %%
# %%sql
# CREATE DATABASE zomato;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# USE zomato;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS orders (
#     order_id INT AUTO_INCREMENT PRIMARY KEY,
#     user_id INT,
#     item_id INT,
#     quantity INT NOT NULL,
#     delivery_address VARCHAR(255) NOT NULL,
#     order_date TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO orders (user_id, item_id, quantity, delivery_address) VALUES
# (1, 1, 2, '123 Main St'),
# (2, 2, 1, '456 Oak Rd'),
# (3, 3, 3, '789 Pine Ave');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# []

# %%
# %%sql
# select * from orders;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 1, 1, 2, '123 Main St', datetime.datetime(2025, 12, 23, 18, 33, 20)),
#  (2, 2, 2, 1, '456 Oak Rd', datetime.datetime(2025, 12, 23, 18, 33, 20)),
#  (3, 3, 3, 3, '789 Pine Ave', datetime.datetime(2025, 12, 23, 18, 33, 20))]

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS categories (
#     category_id INT AUTO_INCREMENT PRIMARY KEY,
#     category_name VARCHAR(255) NOT NULL
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO categories (category_name) VALUES
# ('Vegetarian'),
# ('Non-Vegetarian'),
# ('Vegan');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# []

# %%
# %%sql
# select * from categories;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'Vegetarian'), (2, 'Non-Vegetarian'), (3, 'Vegan')]

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS items (
#     item_id INT AUTO_INCREMENT PRIMARY KEY,
#     item_name VARCHAR(255) NOT NULL,
#     price DECIMAL(10, 2) NOT NULL,
#     category_id INT
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO items (item_name, price, category_id) VALUES
# ('Biriyani', 150.00, 2),
# ('Paneer', 100.00, 1),
# ('Butter Chicken', 200.00, 2);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# []

# %%
# %%sql
# select * from items;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'Biriyani', Decimal('150.00'), 2),
#  (2, 'Paneer', Decimal('100.00'), 1),
#  (3, 'Butter Chicken', Decimal('200.00'), 2)]

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS order_items (
#     order_item_id INT AUTO_INCREMENT PRIMARY KEY,
#     order_id INT,
#     item_id INT,
#     quantity INT NOT NULL,
#     price DECIMAL(10, 2),
#     FOREIGN KEY (item_id) REFERENCES items(item_id)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO order_items (order_id, item_id, quantity, price) VALUES
# (1, 1, 2, 150.00),
# (2, 2, 1, 100.00),
# (3, 3, 3, 200.00);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# []

# %%
# %%sql
# select * from order_items;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 1, 1, 2, Decimal('150.00')),
#  (2, 2, 2, 1, Decimal('100.00')),
#  (3, 3, 3, 3, Decimal('200.00'))]

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS payments (
#     payment_id INT AUTO_INCREMENT PRIMARY KEY,
#     order_id INT,
#     payment_method VARCHAR(50),
#     payment_status VARCHAR(50),
#     amount DECIMAL(10, 2),
#     paid_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO payments (order_id, payment_method, payment_status, amount) VALUES
# (1, 'Credit Card', 'Paid', 300.00),
# (2, 'Debit Card', 'Paid', 100.00),
# (3, 'GPay', 'Pending', 600.00);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# []

# %%
# %%sql
# select * from payments;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 1, 'Credit Card', 'Paid', Decimal('300.00'), datetime.datetime(2025, 12, 23, 18, 37, 52)),
#  (2, 2, 'Debit Card', 'Paid', Decimal('100.00'), datetime.datetime(2025, 12, 23, 18, 37, 52)),
#  (3, 3, 'GPay', 'Pending', Decimal('600.00'), datetime.datetime(2025, 12, 23, 18, 37, 52))]

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS customers (
#     user_id INT PRIMARY KEY,
#     first_name VARCHAR(255),
#     last_name VARCHAR(255),
#     phone_number VARCHAR(15),
#     email VARCHAR(255)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO customers (user_id, first_name, last_name, phone_number, email) VALUES
# (1, 'John', 'Doe', '123-456-7890', 'john.doe@example.com'),
# (2, 'Jane', 'Smith', '987-654-3210', 'jane.smith@example.com'),
# (3, 'Alice', 'Johnson', '111-222-3333', 'alice.johnson@example.com'),
# (4, 'Bob', 'Brown', '444-555-6666', 'bob.brown@example.com'),
# (5, 'Gowtham', 'Kumar', '777-888-9999', 'gowtham.kumar@example.com');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# []

# %%
# %%sql
# select * from customers;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# [(1, 'John', 'Doe', '123-456-7890', 'john.doe@example.com'),
#  (2, 'Jane', 'Smith', '987-654-3210', 'jane.smith@example.com'),
#  (3, 'Alice', 'Johnson', '111-222-3333', 'alice.johnson@example.com'),
#  (4, 'Bob', 'Brown', '444-555-6666', 'bob.brown@example.com'),
#  (5, 'Gowtham', 'Kumar', '777-888-9999', 'gowtham.kumar@example.com')]

# %%
# %%sql
#
# #Total Revenue from All Orders (1)
# SELECT SUM(oi.price * oi.quantity) AS total_revenue
# FROM order_items oi;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(Decimal('1000.00'),)]

# %%
# %%sql
#
# #Revenue by Item (2)
# SELECT i.item_name, SUM(oi.price * oi.quantity) AS total_revenue
# FROM order_items oi
# JOIN items i ON oi.item_id = i.item_id
# GROUP BY i.item_name
# ORDER BY total_revenue DESC;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('Butter Chicken', Decimal('600.00')),
#  ('Biriyani', Decimal('300.00')),
#  ('Paneer', Decimal('100.00'))]

# %%
# %%sql
#
# #Revenue by Payment Method (3)
# SELECT p.payment_method, SUM(p.amount) AS total_revenue
# FROM payments p
# JOIN orders o ON p.order_id = o.order_id
# GROUP BY p.payment_method;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('Credit Card', Decimal('300.00')),
#  ('Debit Card', Decimal('100.00')),
#  ('GPay', Decimal('600.00'))]

# %%
# %%sql
#
# # Total Revenue by Date (4)
# SELECT DATE(p.paid_at) AS date, SUM(p.amount) AS daily_revenue
# FROM payments p
# GROUP BY DATE(p.paid_at)
# ORDER BY date;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(datetime.date(2025, 12, 23), Decimal('1000.00'))]

# %%
# %%sql
#
# #Orders by Payment Status (5)
# SELECT p.payment_status, COUNT(o.order_id) AS total_orders
# FROM payments p
# JOIN orders o ON p.order_id = o.order_id
# GROUP BY p.payment_status;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [('Paid', 2), ('Pending', 1)]

# %%
# %%sql
#
# #Items Purchased in Specific Order (6)
# SELECT oi.order_id, i.item_name, oi.quantity, oi.price
# FROM order_items oi
# JOIN items i ON oi.item_id = i.item_id
# WHERE oi.order_id = 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(1, 'Biriyani', 2, Decimal('150.00'))]

# %%
# %%sql
#
# #Customer Details with Orders (7)
# SELECT
#     c.first_name,
#     c.last_name,
#     c.phone_number,
#     c.email,
#     o.order_id,
#     o.delivery_address,
#     oi.item_id,
#     oi.quantity
# FROM orders o
# JOIN order_items oi ON o.order_id = oi.order_id
# JOIN customers c ON o.user_id = c.user_id;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('John', 'Doe', '123-456-7890', 'john.doe@example.com', 1, '123 Main St', 1, 2),
#  ('Jane', 'Smith', '987-654-3210', 'jane.smith@example.com', 2, '456 Oak Rd', 2, 1),
#  ('Alice', 'Johnson', '111-222-3333', 'alice.johnson@example.com', 3, '789 Pine Ave', 3, 3)]

# %%
# %%sql
#
# #Revenue by Customer (8)
# SELECT
#     c.first_name,
#     c.last_name,
#     c.phone_number,
#     c.email,
#     SUM(oi.price * oi.quantity) AS total_revenue
# FROM orders o
# JOIN order_items oi ON o.order_id = oi.order_id
# JOIN customers c ON o.user_id = c.user_id
# GROUP BY c.user_id
# ORDER BY total_revenue DESC;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('Alice', 'Johnson', '111-222-3333', 'alice.johnson@example.com', Decimal('600.00')),
#  ('John', 'Doe', '123-456-7890', 'john.doe@example.com', Decimal('300.00')),
#  ('Jane', 'Smith', '987-654-3210', 'jane.smith@example.com', Decimal('100.00'))]
